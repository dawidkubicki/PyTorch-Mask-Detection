# %% [markdown]
# Plan of attack
#
# 1. Data Extraction - DataFrame with label 0 (not-masked) and 1 (masked)
# 2. Data Augmentation
# 3. Splitting data for the train, valid and test
# 4. Building the model
# 5. Actual training on GPU
# 6. Testing on real video with openCV

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torchvision.utils import make_grid
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import os

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.cuda.current_device()
print(device)
# Out:
# 0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda

# %%
torch.cuda.get_device_name()
# Out:
# 'GeForce RTX 3080'

# %%
# import splitfolders

# path = '/home/dawidkubicki/Datasets/face-mask/input/'
# output = '/home/dawidkubicki/Datasets/face-mask/output'

# splitfolders.ratio(path, output=output, seed=1337, ratio=(.7, 0.2,0.1))

# %%
train_transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomHorizontalFlip(),
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
val_transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
root = '/home/dawidkubicki/AI-Projects/PyTorch-Mask-Detection/output'

train_data = datasets.ImageFolder(os.path.join(root, 'train'), transform=train_transform)
val_data = datasets.ImageFolder(os.path.join(root, 'val'), transform=val_transform)

torch.manual_seed(1337)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_data, batch_size=16, shuffle=False, pin_memory=True)

class_names = train_data.classes

# %%
class_names
# Out:
# ['with_mask', 'without_mask']

# %%
len(train_data)
# Out:
# 5286

# %%
len(val_data)
# Out:
# 1510

# %%
for image, label in train_loader:
    break

# %%
image.shape
# Out:
# torch.Size([16, 3, 224, 224])

# %%
label
# Out:
# tensor([1, 0, 0, 0, 0, 1, 1, 0, 1, 0, 1, 1, 0, 1, 0, 0])

# %%
plt.imshow(np.transpose(image[0].numpy(), (1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
im = make_grid(image, nrow=5)

inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.255],
    std=[1/0.229, 1/0.224, 1/0.255]
)

im_inv = inv_normalize(im)

plt.figure(figsize=(20,9))
plt.imshow(np.transpose(im_inv.numpy(), (1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class ConvNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3,6,3,1)
        self.conv2 = nn.Conv2d(6,16,3,1)
        self.fc1 = nn.Linear(54*54*16, 220)
        self.fc2 = nn.Linear(220, 100)
        self.fc3 = nn.Linear(100,2)
        
    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 54*54*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        
        return F.log_softmax(X, dim=1)

# %%
gpumodel = ConvNetwork().cuda()

# %%
next(gpumodel.parameters()).is_cuda
# Out:
# True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(gpumodel.parameters(), lr=1e-3)

# %%
EPOCHS = 10

losses = []
train_losses = []
test_losses = []
train_correct = []
test_correct = []

import time

start_time = time.time()

for epoch in range(EPOCHS):
    
    trn_correct = 0
    tst_correct = 0
    
    for batch, (X_train, y_train) in enumerate(train_loader):
        batch += 1
    
        X_train, y_train = X_train.to(device), y_train.to(device)
        
        y_pred = gpumodel(X_train)
        loss = criterion(y_pred, y_train)
        
        predicted = torch.max(y_pred.data,1)[1]
        batch_corr = (predicted==y_train).sum()
        trn_correct += batch_corr
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if batch%200 == 0:
            print(f"Epoch: {epoch}, batch: {batch}, loss: {loss.item()}")
            
    train_losses.append(loss)
    train_correct.append(trn_correct)
    
    
    with torch.no_grad():
        for b, (X_val, y_test) in enumerate(val_loader):
            
            X_val, y_test = X_val.to(device), y_test.to(device)
            
            y_val = gpumodel(X_val)
            predicted = torch.max(y_val.data, 1)[1]
            batch_corr = (predicted==y_test).sum()
            tst_correct += batch_corr
    
    loss = criterion(y_val, y_test)
    test_losses.append(loss)
    test_correct.append(tst_correct)
    
        
total_time = time.time() - start_time
print(f"Training took {total_time/60} mins")
# Out:
# Epoch: 0, batch: 200, loss: 0.3502558767795563
# Epoch: 1, batch: 200, loss: 0.1562989205121994
# Epoch: 2, batch: 200, loss: 0.0481717512011528
# Epoch: 3, batch: 200, loss: 0.02303718589246273
# Epoch: 4, batch: 200, loss: 0.15300875902175903
# Epoch: 5, batch: 200, loss: 0.0638028159737587
# Epoch: 6, batch: 200, loss: 0.06581626832485199
# Epoch: 7, batch: 200, loss: 0.0028051070403307676
# Epoch: 8, batch: 200, loss: 0.09046173095703125
# Epoch: 9, batch: 200, loss: 0.015069939196109772
# Training took 3.3096366842587788 mins

# %%
torch.save(gpumodel.state_dict(), "myFaceMaskModel.pt")

# %%
plt.plot(train_losses, label="Train losses")
plt.plot(test_losses, label="Test losses")
plt.legend()

# %%
plt.plot([t/1000 for t in train_correct], label='training accuracy')
plt.plot([t/100 for t in test_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();

# %%
num_c = test_correct[-1].item()
print(num_c*100 / 3000)
# Out:
# 47.56666666666667

# %%
test_data = datasets.ImageFolder(os.path.join(root, 'test'), transform=val_transform)

image_index = 20

im = inv_normalize(test_data[image_index][0])
plt.imshow(np.transpose(im.numpy(), (1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_data[image_index][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
gpumodel.eval()

with torch.no_grad():
    new_pred = gpumodel(test_data[image_index][0].view(1,3,224,224).cuda()).argmax()
    
class_names[new_pred.item()]
# Out:
# 'with_mask'
